# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("Ice Cream Ratings.csv")
df
# Out:
#        Date  Flavor Rating  Texture Rating  Overall Rating
# 0  1/1/2022       0.223090        0.040220        0.600129
# 1  1/2/2022       0.635886        0.938476        0.106264
# 2  1/3/2022       0.442323        0.044154        0.598112
# 3  1/4/2022       0.389128        0.549676        0.489353
# 4  1/5/2022       0.386887        0.519439        0.988280
# 5  1/6/2022       0.877984        0.193588        0.832827
# 6  1/7/2022       0.140995        0.325110        0.105147

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            7 non-null      object
#  1   Flavor Rating   7 non-null      float64
#  2   Texture Rating  7 non-null      float64
#  3   Overall Rating  7 non-null      float64
# dtypes: float64(3), object(1)
# memory usage: 268.0+ bytes

# %%
df.shape
# Out:
# (7, 4)

# %% [markdown]
# # Top 5 infomation

# %%
df.head(4)
# Out:
#        Date  Flavor Rating  Texture Rating  Overall Rating
# 0  1/1/2022       0.223090        0.040220        0.600129
# 1  1/2/2022       0.635886        0.938476        0.106264
# 2  1/3/2022       0.442323        0.044154        0.598112
# 3  1/4/2022       0.389128        0.549676        0.489353

# %%
df.iloc[2]
# Out:
# Date              1/3/2022
# Flavor Rating     0.442323
# Texture Rating    0.044154
# Overall Rating    0.598112
# Name: 2, dtype: object

# %%
pd.set_option

# %%
df["Texture Rating"].describe()
# Out:
# count    7.000000
# mean     0.372952
# std      0.322952
# min      0.040220
# 25%      0.118871
# 50%      0.325110
# 75%      0.534557
# max      0.938476
# Name: Texture Rating, dtype: float64

# %%
df.isnull().sum()
# Out:
# Date              0
# Flavor Rating     0
# Texture Rating    0
# Overall Rating    0
# dtype: int64

# %%
df['Overall Rating'].unique()
# Out:
# array([0.6001293 , 0.1062636 , 0.59811156, 0.48935315, 0.98827956,
#        0.83282696, 0.1051474 ])

# %%
df.sort_values(by="Texture Rating",ascending=False)
# Out:
#        Date  Flavor Rating  Texture Rating  Overall Rating
# 1  1/2/2022       0.635886        0.938476        0.106264
# 3  1/4/2022       0.389128        0.549676        0.489353
# 4  1/5/2022       0.386887        0.519439        0.988280
# 6  1/7/2022       0.140995        0.325110        0.105147
# 5  1/6/2022       0.877984        0.193588        0.832827
# 2  1/3/2022       0.442323        0.044154        0.598112
# 0  1/1/2022       0.223090        0.040220        0.600129

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(title="ice",xlabel="Day",ylabel="Date")
# Out:
# <Axes: title={'center': 'ice'}, xlabel='Day', ylabel='Date'>

# %%
df.plot.barh()
# Out:
# <Axes: >

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.plot.area(figsize=(15,5))
# Out:
# <Axes: >

# %%
df.plot.pie(y='Flavor Rating',figsize=(10,10))
# Out:
# <Axes: ylabel='Flavor Rating'>
